# %% [markdown]
# CAR SELLING PREDICTION

# %%
#Import the libraries 
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 #Loading dataset into memory
Car=pd.read_csv('car data.csv')

# %%
#preview the dataset 
Car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
#Drop null value if any
Car=Car.dropna()

# %%
Car.shape
# Out:
# (301, 9)

# %%
Car.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
#Viewing the datatype of each column
Car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# describe the dataset
Car.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
#The absolute value of missing numbers
Car.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
sns.histplot(Car['Selling_Price'])#'price' is the variable target column
plt.show()

# %%
sns.scatterplot(x='Selling_Price',y='Present_Price',data=Car,hue='Fuel_Type')
plt.show()
sns.scatterplot(x='Selling_Price',y='Year',data=Car,hue='Fuel_Type')
plt.show()

# %%
#cleaning dataset by dropping duplicates values
Car.drop_duplicates()
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms  Owner  Fuel_Type_n
# 0    2014           3.35           5.59       27000      0            2
# 1    2013           4.75           9.54       43000      0            1
# 2    2017           7.25           9.85        6900      0            2
# 3    2011           2.85           4.15        5200      0            2
# 4    2014           4.60           6.87       42450      0            1
# ..    ...            ...            ...         ...    ...          ...
# 296  2016           9.50          11.60       33988      0            1
# 297  2015           4.00           5.90       60000      0            2
# 298  2009           3.35          11.00       87934      0            2
# 299  2017          11.50          12.50        9000      0            1
# 300  2016           5.30           5.90        5464      0            2
#
# [299 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
Car['Fuel_Type_n']=le.fit_transform(Car['Fuel_Type'])

# %%
Car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner  Fuel_Type_n
# 0         Dealer       Manual      0            2
# ...

# %%
#Equate dataframe feature variable while droping some columns
Car=Car.drop(columns=['Fuel_Type','Selling_type','Transmission','Car_Name'])
Car
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms  Owner  Fuel_Type_n
# 0    2014           3.35           5.59       27000      0            2
# 1    2013           4.75           9.54       43000      0            1
# 2    2017           7.25           9.85        6900      0            2
# 3    2011           2.85           4.15        5200      0            2
# 4    2014           4.60           6.87       42450      0            1
# ..    ...            ...            ...         ...    ...          ...
# 296  2016           9.50          11.60       33988      0            1
# 297  2015           4.00           5.90       60000      0            2
# 298  2009           3.35          11.00       87934      0            2
# 299  2017          11.50          12.50        9000      0            1
# 300  2016           5.30           5.90        5464      0            2
#
# [301 rows x 6 columns]

# %%
Car
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms  Owner  Fuel_Type_n
# 0    2014           3.35           5.59       27000      0            2
# 1    2013           4.75           9.54       43000      0            1
# 2    2017           7.25           9.85        6900      0            2
# 3    2011           2.85           4.15        5200      0            2
# 4    2014           4.60           6.87       42450      0            1
# ..    ...            ...            ...         ...    ...          ...
# 296  2016           9.50          11.60       33988      0            1
# 297  2015           4.00           5.90       60000      0            2
# 298  2009           3.35          11.00       87934      0            2
# 299  2017          11.50          12.50        9000      0            1
# 300  2016           5.30           5.90        5464      0            2
#
# [301 rows x 6 columns]

# %%
Car.isnull().sum()
# Out:
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Owner            0
# Fuel_Type_n      0
# dtype: int64

# %%
X=Car.drop(columns='Selling_Price')

# %%
X
# Out:
#      Year  Present_Price  Driven_kms  Owner  Fuel_Type_n
# 0    2014           5.59       27000      0            2
# 1    2013           9.54       43000      0            1
# 2    2017           9.85        6900      0            2
# 3    2011           4.15        5200      0            2
# 4    2014           6.87       42450      0            1
# ..    ...            ...         ...    ...          ...
# 296  2016          11.60       33988      0            1
# 297  2015           5.90       60000      0            2
# 298  2009          11.00       87934      0            2
# 299  2017          12.50        9000      0            1
# 300  2016           5.90        5464      0            2
#
# [301 rows x 5 columns]

# %%
y=Car['Selling_Price']

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
#Splitting the data into train and test sets
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.2,random_state=42)

# %%
#Assign an initial train to the LinearRegression model
from sklearn.linear_model import LinearRegression

# %%
#Fitting the model
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_prediction=model.predict(X_test)
y_prediction
# Out:
# array([ 1.03653489e+00,  9.82627346e+00,  5.40512835e+00, -5.58803440e-01,
#         1.12946154e+01,  6.37040392e+00,  1.33666016e+00,  1.47182395e+00,
#         1.40844354e+00,  6.72839678e+00,  9.10510211e+00,  6.75701169e-01,
#         8.29042968e+00,  2.07955377e+00,  6.18522787e+00,  1.61632509e+00,
#         1.50059921e+00,  1.33120227e+01,  1.81320809e+00,  2.90816165e+00,
#         1.02646931e+00,  7.76570769e+00,  6.48726601e+00,  3.03368396e+00,
#         8.77074313e-01,  3.78477900e+00,  5.10640003e+00,  2.59201084e+00,
#         2.31039830e+00,  1.86214321e+00,  9.06303784e-01,  8.59845770e+00,
#        -1.09532739e-03,  2.33976795e+00,  7.72769690e+00,  4.30551326e+00,
#         7.54598505e+00,  9.65995737e+00,  1.61049282e+00,  1.02782790e+01,
#         5.25678449e+00,  1.85334325e+00,  4.54976578e+00,  9.80268855e-02,
#         6.52284844e+00,  5.43210962e-01,  8.29946359e+00,  1.18316935e+01,
# ...

# %%
from sklearn.metrics import r2_score,mean_absolute_error

# %%
r2=r2_score(y_test,y_prediction)

# %%
mae=mean_absolute_error(y_test,y_prediction)
print(f'R-Squared:{r2}')
print(f'Mean,Absolute,Error:{mae}')
# Out:
# R-Squared:0.7570342586959506
# Mean,Absolute,Error:1.3275815211620385
